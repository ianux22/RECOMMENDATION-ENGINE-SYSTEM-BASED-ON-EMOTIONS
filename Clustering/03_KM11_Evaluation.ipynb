# %% [markdown]
# # NEW KM11

# %%
import pandas as pd

movie_sent= pd.read_excel(r"C:\Users\leopa\Google Drive\Library\George Brown\II Semester\DATA PROJECT CAPSTONE PROJECT\Magid Capstone Project\movie_sent_km11.xlsx", index_col=0)
movie_sent
# Out:
#           intelligent      real  touching  relatable       sad  romantic  \
# movie_id
# 8984         0.189474  0.147368  0.242105   0.168421  0.073684  0.431579
# 8988         0.193548  0.225806  0.215054   0.172043  0.053763  0.247312
# 8991         0.260417  0.177083  0.229167   0.104167  0.031250  0.500000
# 8992         0.239130  0.173913  0.173913   0.184783  0.097826  0.184783
# 8995         0.228261  0.130435  0.239130   0.119565  0.076087  0.271739
# ...               ...       ...       ...        ...       ...       ...
# 13526        0.042105  0.031579  0.042105   0.147368  0.031579  0.084211
# 13527        0.329670  0.043956  0.098901   0.043956  0.120879  0.010989
# 13528        0.018868  0.037736  0.037736   0.018868  0.018868  0.000000
# 13529        0.125786  0.037736  0.113208   0.056604  0.106918  0.006289
# 13532        0.222222  0.049383  0.037037   0.049383  0.049383  0.012346
#
#           informative      mean      fake  glamorous  ...  \
# ...

# %% [markdown]
# # Number of movies per each cluster

# %%
movie_sent.KM11.value_counts()
# Out:
# 8    414
# 1    384
# 7    374
# 6    334
# 3    305
# 5    250
# 9    250
# 4    165
# 0    142
# Name: KM11, dtype: int64

# %%
movie_sent.drop(columns=['movie_name'])
# Out:
#           intelligent      real  touching  relatable       sad  romantic  \
# movie_id
# 8984         0.189474  0.147368  0.242105   0.168421  0.073684  0.431579
# 8988         0.193548  0.225806  0.215054   0.172043  0.053763  0.247312
# 8991         0.260417  0.177083  0.229167   0.104167  0.031250  0.500000
# 8992         0.239130  0.173913  0.173913   0.184783  0.097826  0.184783
# 8995         0.228261  0.130435  0.239130   0.119565  0.076087  0.271739
# ...               ...       ...       ...        ...       ...       ...
# 13526        0.042105  0.031579  0.042105   0.147368  0.031579  0.084211
# 13527        0.329670  0.043956  0.098901   0.043956  0.120879  0.010989
# 13528        0.018868  0.037736  0.037736   0.018868  0.018868  0.000000
# 13529        0.125786  0.037736  0.113208   0.056604  0.106918  0.006289
# 13532        0.222222  0.049383  0.037037   0.049383  0.049383  0.012346
#
#           informative      mean      fake  glamorous  ...  \
# ...

# %%
movie_sent_KM11_2 = pd.get_dummies(movie_sent, columns=['KM11'])
movie_sent_KM11_2.columns
# Out:
# Index(['intelligent', 'real', 'touching', 'relatable', 'sad', 'romantic',
#        'informative', 'mean', 'fake', 'glamorous', 'original', 'predictable',
#        'fresh', 'mindless', 'unrelatable', 'imaginative', 'wholesome',
#        'inspiring', 'shallow', 'edgy', 'fastpaced', 'disturbing', 'dramatic',
#        'outrageous', 'exciting', 'calming', 'slow', 'unoriginal', 'uplifting',
#        'sexy', 'deep', 'scary', 'thirlling_susp', 'fun_funny',
#        'info_real_int_insp', 'fun_outrag_mindless',
#        'fastpaced_thrilling_exciting', 'scary_dist_edgy_thrill',
#        'origi_imagin_fresh_imag', 'sad_dramatic_deep_touching',
#        'fake_unrel_unorig_predic', 'sexy_glam_rom',
#        'touching_wholesome_uplifting', 'mean_edgy', 'movie_name', 'KM11_0',
#        'KM11_1', 'KM11_3', 'KM11_4', 'KM11_5', 'KM11_6', 'KM11_7', 'KM11_8',
#        'KM11_9'],
#       dtype='object')

# %%
movie_sent_KM11_2['KM11'] = movie_sent['KM11']
movie_sent_KM11_2.columns
# Out:
# Index(['intelligent', 'real', 'touching', 'relatable', 'sad', 'romantic',
#        'informative', 'mean', 'fake', 'glamorous', 'original', 'predictable',
#        'fresh', 'mindless', 'unrelatable', 'imaginative', 'wholesome',
#        'inspiring', 'shallow', 'edgy', 'fastpaced', 'disturbing', 'dramatic',
#        'outrageous', 'exciting', 'calming', 'slow', 'unoriginal', 'uplifting',
#        'sexy', 'deep', 'scary', 'thirlling_susp', 'fun_funny',
#        'info_real_int_insp', 'fun_outrag_mindless',
#        'fastpaced_thrilling_exciting', 'scary_dist_edgy_thrill',
#        'origi_imagin_fresh_imag', 'sad_dramatic_deep_touching',
#        'fake_unrel_unorig_predic', 'sexy_glam_rom',
#        'touching_wholesome_uplifting', 'mean_edgy', 'movie_name', 'KM11_0',
#        'KM11_1', 'KM11_3', 'KM11_4', 'KM11_5', 'KM11_6', 'KM11_7', 'KM11_8',
#        'KM11_9', 'KM11'],
#       dtype='object')

# %% [markdown]
# # Correlation Matrix

# %%
import seaborn as sns
from matplotlib import pyplot

fig, ax = pyplot.subplots(figsize=(10,15))



c= movie_sent_KM11_2.corr()
c = c.iloc[:, 44:53] #insert the right numbers for the cluster variables
c = c.iloc[0:44, :] #this should be always the same, no need to modify
c

sns.heatmap(c, annot=True)

# %% [markdown]
# # KM11_0

# %%
KM11_0 = pd.DataFrame(c.iloc[:, 0])
KM11_0.columns = ['KM11_0']
print('Top positive correlation')
print(' ')
KM11_0.sort_values(by='KM11_0', ascending = False).head()
# Out:
# Top positive correlation
#                                 KM11_0
# uplifting                     0.588804
# touching_wholesome_uplifting  0.574455
# inspiring                     0.562071
# touching                      0.556654
# sad_dramatic_deep_touching    0.414699

# %%
print('Top Negative Correlation')
print(' ')
KM11_0.sort_values(by='KM11_0', ascending = False).tail()
# Out:
# Top Negative Correlation
#                                 KM11_0
# scary_dist_edgy_thrill       -0.194652
# fastpaced_thrilling_exciting -0.195224
# mean_edgy                    -0.209513
# edgy                         -0.213020
# fake_unrel_unorig_predic     -0.235255

# %%
from matplotlib import pyplot

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='uplifting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='inspiring', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='touching_wholesome_uplifting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='touching', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='sad_dramatic_deep_touching', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
import statsmodels.formula.api as smf
import statsmodels.stats.multicomp as multi

print('Tukey Test for uplifting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['uplifting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for uplifting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1603  0.001 -0.1756  -0.145   True
#      0      3  -0.1345  0.001 -0.1503 -0.1187   True
#      0      4  -0.2202  0.001  -0.238 -0.2024   True
#      0      5  -0.2646  0.001 -0.2809 -0.2482   True
#      0      6  -0.2514  0.001  -0.267 -0.2358   True
#      0      7  -0.2444  0.001 -0.2597  -0.229   True
#      0      8  -0.2205  0.001 -0.2356 -0.2054   True
#      0      9  -0.1913  0.001 -0.2076 -0.1749   True
#      1      3   0.0258  0.001  0.0139  0.0377   True
#      1      4  -0.0599  0.001 -0.0743 -0.0454   True
#      1      5  -0.1043  0.001 -0.1169 -0.0916   True
#      1      6  -0.0911  0.001 -0.1028 -0.0795   True
#      1      7  -0.0841  0.001 -0.0954 -0.0728   True
#      1      8  -0.0602  0.001 -0.0712 -0.0492   True
# ...

# %%
print('Tukey Test for touching_wholesome_uplifting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['touching_wholesome_uplifting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for touching_wholesome_uplifting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   -0.154  0.001 -0.1685 -0.1395   True
#      0      3  -0.1316  0.001 -0.1466 -0.1166   True
#      0      4  -0.2455  0.001 -0.2624 -0.2286   True
#      0      5  -0.2943  0.001 -0.3098 -0.2788   True
#      0      6  -0.2668  0.001 -0.2816  -0.252   True
#      0      7  -0.2802  0.001 -0.2947 -0.2656   True
#      0      8  -0.2575  0.001 -0.2718 -0.2432   True
#      0      9  -0.1967  0.001 -0.2122 -0.1812   True
#      1      3   0.0224  0.001  0.0111  0.0337   True
#      1      4  -0.0915  0.001 -0.1052 -0.0778   True
#      1      5  -0.1403  0.001 -0.1523 -0.1283   True
#      1      6  -0.1128  0.001 -0.1239 -0.1018   True
#      1      7  -0.1262  0.001 -0.1369 -0.1155   True
#      1      8  -0.1035  0.001  -0.114 -0.0931   True
# ...

# %%
print('Tukey Test for inspiring')
print(' ')

mc1 = multi.MultiComparison(movie_sent['inspiring'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for inspiring
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1975  0.001 -0.2162 -0.1789   True
#      0      3  -0.1998  0.001  -0.219 -0.1805   True
#      0      4  -0.2285  0.001 -0.2502 -0.2068   True
#      0      5  -0.2933  0.001 -0.3133 -0.2734   True
#      0      6  -0.2495  0.001 -0.2685 -0.2305   True
#      0      7  -0.2679  0.001 -0.2866 -0.2492   True
#      0      8  -0.2807  0.001 -0.2992 -0.2623   True
#      0      9   -0.125  0.001 -0.1449  -0.105   True
#      1      3  -0.0022    0.9 -0.0168  0.0123  False
#      1      4   -0.031  0.001 -0.0486 -0.0133   True
#      1      5  -0.0958  0.001 -0.1112 -0.0804   True
#      1      6  -0.0519  0.001 -0.0661 -0.0377   True
#      1      7  -0.0704  0.001 -0.0842 -0.0566   True
#      1      8  -0.0832  0.001 -0.0966 -0.0697   True
# ...

# %%
print('Tukey Test for touching')
print(' ')

mc1 = multi.MultiComparison(movie_sent['touching'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for touching
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1928  0.001 -0.2147 -0.1709   True
#      0      3  -0.2243  0.001 -0.2469 -0.2017   True
#      0      4  -0.3364  0.001 -0.3618 -0.3109   True
#      0      5  -0.3884  0.001 -0.4118  -0.365   True
#      0      6  -0.3339  0.001 -0.3562 -0.3116   True
#      0      7   -0.376  0.001 -0.3979  -0.354   True
#      0      8   -0.365  0.001 -0.3866 -0.3433   True
#      0      9  -0.2186  0.001  -0.242 -0.1952   True
#      1      3  -0.0315  0.001 -0.0486 -0.0144   True
#      1      4  -0.1436  0.001 -0.1643 -0.1228   True
#      1      5  -0.1955  0.001 -0.2136 -0.1775   True
#      1      6  -0.1411  0.001 -0.1578 -0.1245   True
#      1      7  -0.1832  0.001 -0.1993  -0.167   True
#      1      8  -0.1722  0.001  -0.188 -0.1564   True
# ...

# %%
print('Tukey Test for sad_dramatic_deep_touching')
print(' ')

mc1 = multi.MultiComparison(movie_sent['sad_dramatic_deep_touching'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for sad_dramatic_deep_touching
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1263  0.001  -0.144 -0.1086   True
#      0      3  -0.1754  0.001 -0.1937  -0.157   True
#      0      4   -0.149  0.001 -0.1697 -0.1284   True
#      0      5  -0.1883  0.001 -0.2073 -0.1694   True
#      0      6  -0.1079  0.001  -0.126 -0.0898   True
#      0      7  -0.1846  0.001 -0.2024 -0.1669   True
#      0      8  -0.2336  0.001 -0.2512 -0.2161   True
#      0      9  -0.0506  0.001 -0.0695 -0.0316   True
#      1      3  -0.0491  0.001 -0.0629 -0.0352   True
#      1      4  -0.0227  0.001 -0.0395 -0.0059   True
#      1      5   -0.062  0.001 -0.0767 -0.0474   True
#      1      6   0.0184  0.001  0.0049  0.0319   True
#      1      7  -0.0583  0.001 -0.0715 -0.0452   True
#      1      8  -0.1073  0.001 -0.1201 -0.0946   True
# ...

# %% [markdown]
# # KM11_1

# %%
KM11_1 = pd.DataFrame(c.iloc[:, 1])
KM11_1.columns = ['KM11_1']
print('Top positive correlation')
print(' ')
KM11_1.sort_values(by='KM11_1', ascending = False).head()
# Out:
# Top positive correlation
#                  KM11_1
# romantic       0.820531
# sexy_glam_rom  0.769782
# calming        0.379554
# sexy           0.376643
# glamorous      0.366696

# %%
print('Top Negative Correlation')
print(' ')
KM11_1.sort_values(by='KM11_1', ascending = False).tail()
# Out:
# Top Negative Correlation
#                                 KM11_1
# fastpaced                    -0.319245
# exciting                     -0.321397
# scary_dist_edgy_thrill       -0.352967
# thirlling_susp               -0.396355
# fastpaced_thrilling_exciting -0.403385

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='romantic', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='sexy_glam_rom', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='calming', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='sexy', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='glamorous', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for romantic')
print(' ')

mc1 = multi.MultiComparison(movie_sent['romantic'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for romantic
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.3841  0.001  0.3529  0.4152   True
#      0      3  -0.0168 0.7664 -0.0491  0.0154  False
#      0      4  -0.0416 0.0116 -0.0779 -0.0053   True
#      0      5  -0.0704  0.001 -0.1038 -0.0371   True
#      0      6  -0.0434  0.001 -0.0752 -0.0116   True
#      0      7  -0.0419 0.0011 -0.0732 -0.0107   True
#      0      8  -0.0287 0.0909 -0.0596  0.0021  False
#      0      9  -0.0252 0.3158 -0.0585  0.0082  False
#      1      3  -0.4009  0.001 -0.4253 -0.3766   True
#      1      4  -0.4257  0.001 -0.4552 -0.3961   True
#      1      5  -0.4545  0.001 -0.4803 -0.4288   True
#      1      6  -0.4275  0.001 -0.4512 -0.4038   True
#      1      7   -0.426  0.001 -0.4491  -0.403   True
#      1      8  -0.4128  0.001 -0.4353 -0.3904   True
# ...

# %%
print('Tukey Test for sexy_glam_rom')
print(' ')

mc1 = multi.MultiComparison(movie_sent['sexy_glam_rom'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for sexy_glam_rom
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.1901  0.001  0.1733  0.2069   True
#      0      3  -0.0031    0.9 -0.0204  0.0143  False
#      0      4  -0.0063    0.9 -0.0259  0.0132  False
#      0      5   -0.017 0.0819 -0.0349   0.001  False
#      0      6   0.0048    0.9 -0.0123   0.022  False
#      0      7   0.0019    0.9  -0.015  0.0187  False
#      0      8   0.0109 0.5139 -0.0057  0.0275  False
#      0      9   0.0076    0.9 -0.0104  0.0255  False
#      1      3  -0.1932  0.001 -0.2063 -0.1801   True
#      1      4  -0.1964  0.001 -0.2123 -0.1805   True
#      1      5   -0.207  0.001 -0.2209 -0.1932   True
#      1      6  -0.1852  0.001  -0.198 -0.1725   True
#      1      7  -0.1882  0.001 -0.2006 -0.1758   True
#      1      8  -0.1792  0.001 -0.1913 -0.1671   True
# ...

# %%
print('Tukey Test for calming')
print(' ')

mc1 = multi.MultiComparison(movie_sent['calming'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for calming
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0156  0.002 -0.0276 -0.0035   True
#      0      3  -0.0344  0.001 -0.0469  -0.022   True
#      0      4  -0.0797  0.001 -0.0937 -0.0657   True
#      0      5  -0.0864  0.001 -0.0993 -0.0735   True
#      0      6   -0.078  0.001 -0.0903 -0.0657   True
#      0      7  -0.0912  0.001 -0.1033 -0.0791   True
#      0      8  -0.0788  0.001 -0.0908 -0.0669   True
#      0      9  -0.0608  0.001 -0.0737 -0.0479   True
#      1      3  -0.0189  0.001 -0.0283 -0.0094   True
#      1      4  -0.0641  0.001 -0.0755 -0.0527   True
#      1      5  -0.0708  0.001 -0.0808 -0.0609   True
#      1      6  -0.0624  0.001 -0.0716 -0.0532   True
#      1      7  -0.0756  0.001 -0.0845 -0.0667   True
#      1      8  -0.0633  0.001  -0.072 -0.0546   True
# ...

# %%
print('Tukey Test for sexy')
print(' ')

mc1 = multi.MultiComparison(movie_sent['sexy'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for sexy
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.1274  0.001  0.1028   0.152   True
#      0      3   0.0044    0.9  -0.021  0.0298  False
#      0      4   0.0186 0.5281   -0.01  0.0472  False
#      0      5   0.0261 0.0536 -0.0002  0.0524  False
#      0      6   0.0487  0.001  0.0236  0.0737   True
#      0      7   0.0451  0.001  0.0205  0.0698   True
#      0      8   0.0541  0.001  0.0298  0.0785   True
#      0      9   0.0277 0.0298  0.0014   0.054   True
#      1      3   -0.123  0.001 -0.1422 -0.1039   True
#      1      4  -0.1088  0.001 -0.1321 -0.0855   True
#      1      5  -0.1013  0.001 -0.1217  -0.081   True
#      1      6  -0.0788  0.001 -0.0975   -0.06   True
#      1      7  -0.0823  0.001 -0.1005 -0.0641   True
#      1      8  -0.0733  0.001  -0.091 -0.0555   True
# ...

# %%
print('Tukey Test for glamorous')
print(' ')

mc1 = multi.MultiComparison(movie_sent['glamorous'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for glamorous
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0587  0.001  0.0442  0.0732   True
#      0      3   0.0032    0.9 -0.0118  0.0182  False
#      0      4    0.004    0.9 -0.0129  0.0209  False
#      0      5  -0.0065    0.9  -0.022   0.009  False
#      0      6   0.0093 0.5645 -0.0055  0.0241  False
#      0      7   0.0023    0.9 -0.0122  0.0169  False
#      0      8   0.0073 0.7926 -0.0071  0.0216  False
#      0      9   0.0202 0.0018  0.0047  0.0357   True
#      1      3  -0.0555  0.001 -0.0668 -0.0442   True
#      1      4  -0.0547  0.001 -0.0685  -0.041   True
#      1      5  -0.0652  0.001 -0.0772 -0.0532   True
#      1      6  -0.0494  0.001 -0.0605 -0.0384   True
#      1      7  -0.0564  0.001 -0.0671 -0.0457   True
#      1      8  -0.0514  0.001 -0.0619  -0.041   True
# ...

# %% [markdown]
# # KM11_3

# %%
KM11_3 = pd.DataFrame(c.iloc[:, 2])
KM11_3.columns = ['KM11_3']
print('Top positive correlation')
print(' ')
KM11_3.sort_values(by='KM11_3', ascending = False).head()
# Out:
# Top positive correlation
#                                 KM11_3
# wholesome                     0.469428
# fun_funny                     0.380966
# touching_wholesome_uplifting  0.337986
# fun_outrag_mindless           0.294122
# uplifting                     0.287605

# %%
print('Top Negative Correlation')
print(' ')
KM11_3.sort_values(by='KM11_3', ascending = False).tail()
# Out:
# Top Negative Correlation
#                           KM11_3
# thirlling_susp         -0.293193
# scary_dist_edgy_thrill -0.306568
# mean_edgy              -0.316842
# edgy                   -0.319692
# dramatic               -0.324487

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='wholesome', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fun_funny', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='touching_wholesome_uplifting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fun_outrag_mindless', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='uplifting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for wholesome')
print(' ')

mc1 = multi.MultiComparison(movie_sent['wholesome'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for wholesome
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1089  0.001 -0.1281 -0.0897   True
#      0      3   -0.036  0.001 -0.0559 -0.0161   True
#      0      4    -0.18  0.001 -0.2024 -0.1576   True
#      0      5  -0.2299  0.001 -0.2504 -0.2093   True
#      0      6  -0.2151  0.001 -0.2347 -0.1955   True
#      0      7  -0.2202  0.001 -0.2395 -0.2009   True
#      0      8   -0.187  0.001  -0.206  -0.168   True
#      0      9  -0.1802  0.001 -0.2007 -0.1596   True
#      1      3   0.0729  0.001  0.0578  0.0879   True
#      1      4  -0.0711  0.001 -0.0893 -0.0529   True
#      1      5   -0.121  0.001 -0.1369 -0.1051   True
#      1      6  -0.1062  0.001 -0.1209 -0.0916   True
#      1      7  -0.1114  0.001 -0.1256 -0.0971   True
#      1      8  -0.0782  0.001  -0.092 -0.0643   True
# ...

# %%
print('Tukey Test for touching_wholesome_uplifting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['touching_wholesome_uplifting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for touching_wholesome_uplifting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   -0.154  0.001 -0.1685 -0.1395   True
#      0      3  -0.1316  0.001 -0.1466 -0.1166   True
#      0      4  -0.2455  0.001 -0.2624 -0.2286   True
#      0      5  -0.2943  0.001 -0.3098 -0.2788   True
#      0      6  -0.2668  0.001 -0.2816  -0.252   True
#      0      7  -0.2802  0.001 -0.2947 -0.2656   True
#      0      8  -0.2575  0.001 -0.2718 -0.2432   True
#      0      9  -0.1967  0.001 -0.2122 -0.1812   True
#      1      3   0.0224  0.001  0.0111  0.0337   True
#      1      4  -0.0915  0.001 -0.1052 -0.0778   True
#      1      5  -0.1403  0.001 -0.1523 -0.1283   True
#      1      6  -0.1128  0.001 -0.1239 -0.1018   True
#      1      7  -0.1262  0.001 -0.1369 -0.1155   True
#      1      8  -0.1035  0.001  -0.114 -0.0931   True
# ...

# %%
print('Tukey Test for fun_funny')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fun_funny'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fun_funny
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1    0.075 0.001  0.0245  0.1254   True
#      0      3   0.3585 0.001  0.3063  0.4107   True
#      0      4   0.0806 0.001  0.0218  0.1394   True
#      0      5  -0.1718 0.001 -0.2258 -0.1178   True
#      0      6  -0.1801 0.001 -0.2316 -0.1286   True
#      0      7  -0.0165   0.9 -0.0672  0.0341  False
#      0      8    0.424 0.001  0.3741   0.474   True
#      0      9  -0.1666 0.001 -0.2206 -0.1126   True
#      1      3   0.2835 0.001  0.2441  0.3229   True
#      1      4   0.0056   0.9 -0.0422  0.0535  False
#      1      5  -0.2468 0.001 -0.2885  -0.205   True
#      1      6  -0.2551 0.001 -0.2935 -0.2166   True
#      1      7  -0.0915 0.001 -0.1288 -0.0542   True
#      1      8   0.3491 0.001  0.3127  0.3855   True
# ...

# %%
print('Tukey Test for fun_outrag_mindless')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fun_outrag_mindless'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fun_outrag_mindless
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0392  0.001  0.0187  0.0597   True
#      0      3   0.1423  0.001   0.121  0.1635   True
#      0      4   0.0522  0.001  0.0283  0.0761   True
#      0      5  -0.0241  0.019  -0.046 -0.0022   True
#      0      6  -0.0414  0.001 -0.0623 -0.0205   True
#      0      7   0.0218 0.0286  0.0012  0.0424   True
#      0      8   0.2173  0.001   0.197  0.2376   True
#      0      9  -0.0459  0.001 -0.0678 -0.0239   True
#      1      3   0.1031  0.001   0.087  0.1191   True
#      1      4   0.0129 0.4957 -0.0065  0.0324  False
#      1      5  -0.0633  0.001 -0.0803 -0.0463   True
#      1      6  -0.0806  0.001 -0.0962  -0.065   True
#      1      7  -0.0174 0.0111 -0.0326 -0.0023   True
#      1      8   0.1781  0.001  0.1633  0.1929   True
# ...

# %%
print('Tukey Test for uplifting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['uplifting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for uplifting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1603  0.001 -0.1756  -0.145   True
#      0      3  -0.1345  0.001 -0.1503 -0.1187   True
#      0      4  -0.2202  0.001  -0.238 -0.2024   True
#      0      5  -0.2646  0.001 -0.2809 -0.2482   True
#      0      6  -0.2514  0.001  -0.267 -0.2358   True
#      0      7  -0.2444  0.001 -0.2597  -0.229   True
#      0      8  -0.2205  0.001 -0.2356 -0.2054   True
#      0      9  -0.1913  0.001 -0.2076 -0.1749   True
#      1      3   0.0258  0.001  0.0139  0.0377   True
#      1      4  -0.0599  0.001 -0.0743 -0.0454   True
#      1      5  -0.1043  0.001 -0.1169 -0.0916   True
#      1      6  -0.0911  0.001 -0.1028 -0.0795   True
#      1      7  -0.0841  0.001 -0.0954 -0.0728   True
#      1      8  -0.0602  0.001 -0.0712 -0.0492   True
# ...

# %% [markdown]
# # KM11_4

# %%
KM11_4 = pd.DataFrame(c.iloc[:, 3])
KM11_4.columns = ['KM11_4']
print('Top positive correlation')
print(' ')
KM11_4.sort_values(by='KM11_4', ascending = False).head()
# Out:
# Top positive correlation
#                            KM11_4
# imaginative              0.490491
# origi_imagin_fresh_imag  0.473868
# original                 0.354539
# exciting                 0.297792
# intelligent              0.280746

# %%
print('Top Negative Correlation')
print(' ')
KM11_4.sort_values(by='KM11_4', ascending = False).tail()
# Out:
# Top Negative Correlation
#                             KM11_4
# fake_unrel_unorig_predic -0.113996
# relatable                -0.135675
# unoriginal               -0.140275
# real                     -0.146964
# predictable              -0.165541

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='imaginative', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='origi_imagin_fresh_imag', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='original', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='intelligent', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='exciting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for imaginative')
print(' ')

mc1 = multi.MultiComparison(movie_sent['imaginative'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for imaginative
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0558  0.001 -0.0792 -0.0325   True
#      0      3   0.0462  0.001  0.0221  0.0704   True
#      0      4   0.1792  0.001   0.152  0.2063   True
#      0      5  -0.0257 0.0381 -0.0506 -0.0007   True
#      0      6   -0.006    0.9 -0.0298  0.0178  False
#      0      7   0.0209 0.1231 -0.0025  0.0443  False
#      0      8   -0.026 0.0144 -0.0491 -0.0029   True
#      0      9  -0.0469  0.001 -0.0719  -0.022   True
#      1      3   0.1021  0.001  0.0839  0.1203   True
#      1      4    0.235  0.001  0.2129  0.2571   True
#      1      5   0.0302  0.001  0.0109  0.0495   True
#      1      6   0.0499  0.001  0.0321  0.0676   True
#      1      7   0.0768  0.001  0.0595   0.094   True
#      1      8   0.0299  0.001  0.0131  0.0467   True
# ...

# %%
print('Tukey Test for original')
print(' ')

mc1 = multi.MultiComparison(movie_sent['original'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for original
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   -0.145  0.001 -0.1691 -0.1209   True
#      0      3  -0.0826  0.001 -0.1075 -0.0577   True
#      0      4    0.032  0.012   0.004  0.0601   True
#      0      5  -0.1822  0.001  -0.208 -0.1565   True
#      0      6  -0.0688  0.001 -0.0934 -0.0443   True
#      0      7  -0.1398  0.001 -0.1639 -0.1156   True
#      0      8  -0.1495  0.001 -0.1733 -0.1256   True
#      0      9  -0.0488  0.001 -0.0745 -0.0231   True
#      1      3   0.0624  0.001  0.0436  0.0812   True
#      1      4    0.177  0.001  0.1542  0.1998   True
#      1      5  -0.0372  0.001 -0.0571 -0.0173   True
#      1      6   0.0762  0.001  0.0578  0.0945   True
#      1      7   0.0052    0.9 -0.0126   0.023  False
#      1      8  -0.0045    0.9 -0.0218  0.0129  False
# ...

# %%
print('Tukey Test for origi_imagin_fresh_imag')
print(' ')

mc1 = multi.MultiComparison(movie_sent['origi_imagin_fresh_imag'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for origi_imagin_fresh_imag
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0873  0.001 -0.1014 -0.0733   True
#      0      3   -0.046  0.001 -0.0605 -0.0315   True
#      0      4   0.0564  0.001  0.0401  0.0728   True
#      0      5   -0.109  0.001  -0.124 -0.0939   True
#      0      6   -0.038  0.001 -0.0523 -0.0237   True
#      0      7  -0.0706  0.001 -0.0847 -0.0566   True
#      0      8  -0.0921  0.001  -0.106 -0.0782   True
#      0      9  -0.0266  0.001 -0.0417 -0.0116   True
#      1      3   0.0413  0.001  0.0304  0.0523   True
#      1      4   0.1438  0.001  0.1305   0.157   True
#      1      5  -0.0216  0.001 -0.0332   -0.01   True
#      1      6   0.0493  0.001  0.0386    0.06   True
#      1      7   0.0167  0.001  0.0063  0.0271   True
#      1      8  -0.0048 0.8629 -0.0149  0.0054  False
# ...

# %%
print('Tukey Test for intelligent')
print(' ')

mc1 = multi.MultiComparison(movie_sent['intelligent'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for intelligent
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1172  0.001 -0.1405  -0.094   True
#      0      3  -0.1259  0.001 -0.1499 -0.1018   True
#      0      4   0.0256 0.0825 -0.0015  0.0527  False
#      0      5  -0.1478  0.001 -0.1727 -0.1229   True
#      0      6  -0.0253 0.0269  -0.049 -0.0015   True
#      0      7  -0.1002  0.001 -0.1236 -0.0769   True
#      0      8  -0.1572  0.001 -0.1802 -0.1342   True
#      0      9   0.0292 0.0082  0.0044  0.0541   True
#      1      3  -0.0087 0.8502 -0.0268  0.0095  False
#      1      4   0.1428  0.001  0.1208  0.1648   True
#      1      5  -0.0306  0.001 -0.0499 -0.0114   True
#      1      6    0.092  0.001  0.0742  0.1097   True
#      1      7    0.017 0.0565 -0.0002  0.0342  False
#      1      8    -0.04  0.001 -0.0568 -0.0232   True
# ...

# %%
print('Tukey Test for exciting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['exciting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for exciting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0238 0.1225 -0.0504  0.0028  False
#      0      3   0.0449  0.001  0.0174  0.0724   True
#      0      4   0.2127  0.001  0.1817  0.2437   True
#      0      5   0.0319 0.0147  0.0035  0.0604   True
#      0      6   0.1123  0.001  0.0852  0.1394   True
#      0      7    0.231  0.001  0.2043  0.2576   True
#      0      8    0.017 0.5338 -0.0093  0.0433  False
#      0      9   0.0347 0.0049  0.0062  0.0631   True
#      1      3   0.0687  0.001  0.0479  0.0895   True
#      1      4   0.2365  0.001  0.2113  0.2617   True
#      1      5   0.0557  0.001  0.0337  0.0777   True
#      1      6   0.1361  0.001  0.1158  0.1563   True
#      1      7   0.2548  0.001  0.2351  0.2744   True
#      1      8   0.0408  0.001  0.0216    0.06   True
# ...

# %% [markdown]
# # KM11_5

# %%
KM11_5 = pd.DataFrame(c.iloc[:, 4])
KM11_5.columns = ['KM11_5']
print('Top positive correlation')
print(' ')
KM11_5.sort_values(by='KM11_5', ascending = False).head()
# Out:
# Top positive correlation
#                           KM11_5
# scary                   0.746202
# scary_dist_edgy_thrill  0.551405
# disturbing              0.526676
# thirlling_susp          0.346154
# fake                    0.330708

# %%
print('Top Negative Correlation')
print(' ')
KM11_5.sort_values(by='KM11_5', ascending = False).tail()
# Out:
# Top Negative Correlation
#                                 KM11_5
# uplifting                    -0.266234
# origi_imagin_fresh_imag      -0.271392
# fun_funny                    -0.279794
# touching_wholesome_uplifting -0.287035
# fresh                        -0.293319

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='scary', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='scary_dist_edgy_thrill', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='disturbing', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='thirlling_susp', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fake', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for scary')
print(' ')

mc1 = multi.MultiComparison(movie_sent['scary'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for scary
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0044    0.9 -0.0211    0.03  False
#      0      3   0.0015    0.9 -0.0249   0.028  False
#      0      4   0.0359 0.0058  0.0061  0.0657   True
#      0      5   0.3823  0.001  0.3549  0.4096   True
#      0      6   0.1201  0.001   0.094  0.1461   True
#      0      7   0.0441  0.001  0.0184  0.0697   True
#      0      8   0.0071    0.9 -0.0182  0.0324  False
#      0      9   0.0409  0.001  0.0135  0.0682   True
#      1      3  -0.0029    0.9 -0.0229  0.0171  False
#      1      4   0.0315 0.0019  0.0072  0.0557   True
#      1      5   0.3778  0.001  0.3567  0.3989   True
#      1      6   0.1156  0.001  0.0961  0.1351   True
#      1      7   0.0396  0.001  0.0207  0.0585   True
#      1      8   0.0026    0.9 -0.0158   0.021  False
# ...

# %%
print('Tukey Test for disturbing')
print(' ')

mc1 = multi.MultiComparison(movie_sent['disturbing'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for disturbing
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0023    0.9 -0.0171  0.0216  False
#      0      3   -0.008    0.9  -0.028   0.012  False
#      0      4   0.0257 0.0122  0.0032  0.0482   True
#      0      5   0.2038  0.001  0.1831  0.2245   True
#      0      6   0.1472  0.001  0.1274  0.1669   True
#      0      7    0.016 0.2032 -0.0034  0.0354  False
#      0      8    0.006    0.9 -0.0131  0.0251  False
#      0      9   0.0836  0.001  0.0629  0.1043   True
#      1      3  -0.0103 0.4685 -0.0254  0.0048  False
#      1      4   0.0234 0.0024  0.0051  0.0417   True
#      1      5   0.2015  0.001  0.1855  0.2175   True
#      1      6   0.1449  0.001  0.1302  0.1596   True
#      1      7   0.0137 0.0712 -0.0006   0.028  False
#      1      8   0.0037    0.9 -0.0102  0.0177  False
# ...

# %%
print('Tukey Test for scary_dist_edgy_thrill')
print(' ')

mc1 = multi.MultiComparison(movie_sent['scary_dist_edgy_thrill'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for scary_dist_edgy_thrill
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0044    0.9 -0.0218  0.0129  False
#      0      3  -0.0036    0.9 -0.0216  0.0144  False
#      0      4   0.1252  0.001  0.1049  0.1454   True
#      0      5    0.288  0.001  0.2694  0.3065   True
#      0      6   0.2131  0.001  0.1954  0.2308   True
#      0      7   0.1453  0.001  0.1279  0.1627   True
#      0      8   0.0113 0.5153 -0.0059  0.0285  False
#      0      9   0.0965  0.001  0.0779   0.115   True
#      1      3   0.0008    0.9 -0.0127  0.0144  False
#      1      4   0.1296  0.001  0.1131   0.146   True
#      1      5   0.2924  0.001   0.278  0.3068   True
#      1      6   0.2176  0.001  0.2043  0.2308   True
#      1      7   0.1497  0.001  0.1369  0.1625   True
#      1      8   0.0157 0.0033  0.0032  0.0282   True
# ...

# %%
print('Tukey Test for thirlling_susp')
print(' ')

mc1 = multi.MultiComparison(movie_sent['thirlling_susp'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for thirlling_susp
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0441 0.0065  -0.081 -0.0072   True
#      0      3  -0.0087    0.9 -0.0469  0.0294  False
#      0      4   0.3457  0.001  0.3027  0.3887   True
#      0      5   0.4374  0.001  0.3979  0.4769   True
#      0      6   0.4147  0.001   0.377  0.4523   True
#      0      7   0.4134  0.001  0.3764  0.4504   True
#      0      8  -0.0153    0.9 -0.0518  0.0213  False
#      0      9   0.1886  0.001  0.1492  0.2281   True
#      1      3   0.0354 0.0044  0.0066  0.0642   True
#      1      4   0.3898  0.001  0.3548  0.4248   True
#      1      5   0.4815  0.001   0.451  0.5121   True
#      1      6   0.4588  0.001  0.4307  0.4869   True
#      1      7   0.4575  0.001  0.4302  0.4848   True
#      1      8   0.0289 0.0219  0.0023  0.0555   True
# ...

# %%
print('Tukey Test for fake')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fake'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fake
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0175  0.001  0.0069  0.0281   True
#      0      3   0.0296  0.001  0.0186  0.0405   True
#      0      4   0.0333  0.001   0.021  0.0456   True
#      0      5     0.07  0.001  0.0587  0.0813   True
#      0      6   0.0122 0.0131  0.0014   0.023   True
#      0      7   0.0379  0.001  0.0273  0.0485   True
#      0      8   0.0462  0.001  0.0357  0.0567   True
#      0      9    0.007 0.5874 -0.0043  0.0183  False
#      1      3   0.0121  0.001  0.0038  0.0203   True
#      1      4   0.0158  0.001  0.0058  0.0258   True
#      1      5   0.0525  0.001  0.0438  0.0613   True
#      1      6  -0.0053 0.5203 -0.0133  0.0028  False
#      1      7   0.0204  0.001  0.0126  0.0283   True
#      1      8   0.0287  0.001  0.0211  0.0363   True
# ...

# %% [markdown]
# # KM11_6

# %%
KM11_6 = pd.DataFrame(c.iloc[:, 5])
KM11_6.columns = ['KM11_6']
print('Top positive correlation')
print(' ')
KM11_6.sort_values(by='KM11_6', ascending = False).head()
# Out:
# Top positive correlation
#                           KM11_6
# mean_edgy               0.480834
# edgy                    0.458140
# scary_dist_edgy_thrill  0.399517
# disturbing              0.390889
# thirlling_susp          0.370860

# %%
print('Top Negative Correlation')
print(' ')
KM11_6.sort_values(by='KM11_6', ascending = False).tail()
# Out:
# Top Negative Correlation
#                                 KM11_6
# touching_wholesome_uplifting -0.220756
# wholesome                    -0.224696
# uplifting                    -0.251023
# fun_outrag_mindless          -0.314416
# fun_funny                    -0.340708

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='edgy', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='scary_dist_edgy_thrill', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='mean_edgy', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='thirlling_susp', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='dramatic', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

sns.boxplot(y='disturbing', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for edgy')
print(' ')

mc1 = multi.MultiComparison(movie_sent['edgy'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for edgy
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0197 0.0224  0.0015  0.0379   True
#      0      3   0.0007    0.9 -0.0181  0.0196  False
#      0      4   0.0934  0.001  0.0722  0.1146   True
#      0      5   0.1284  0.001  0.1089  0.1479   True
#      0      6   0.1706  0.001  0.1521  0.1892   True
#      0      7   0.1076  0.001  0.0894  0.1259   True
#      0      8   0.0473  0.001  0.0293  0.0653   True
#      0      9   0.0728  0.001  0.0533  0.0923   True
#      1      3   -0.019 0.0012 -0.0332 -0.0047   True
#      1      4   0.0737  0.001  0.0564   0.091   True
#      1      5   0.1087  0.001  0.0936  0.1238   True
#      1      6   0.1509  0.001   0.137  0.1648   True
#      1      7   0.0879  0.001  0.0745  0.1014   True
#      1      8   0.0276  0.001  0.0144  0.0407   True
# ...

# %%
print('Tukey Test for mean_edgy')
print(' ')

mc1 = multi.MultiComparison(movie_sent['mean_edgy'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for mean_edgy
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0136 0.0036  0.0027  0.0245   True
#      0      3   0.0001    0.9 -0.0112  0.0114  False
#      0      4    0.047  0.001  0.0343  0.0597   True
#      0      5   0.0786  0.001  0.0669  0.0903   True
#      0      6   0.1041  0.001  0.0929  0.1152   True
#      0      7    0.056  0.001   0.045  0.0669   True
#      0      8   0.0272  0.001  0.0164   0.038   True
#      0      9   0.0487  0.001   0.037  0.0604   True
#      1      3  -0.0135  0.001  -0.022 -0.0049   True
#      1      4   0.0334  0.001  0.0231  0.0437   True
#      1      5    0.065  0.001   0.056  0.0741   True
#      1      6   0.0905  0.001  0.0822  0.0988   True
#      1      7   0.0424  0.001  0.0343  0.0505   True
#      1      8   0.0136  0.001  0.0058  0.0215   True
# ...

# %%
print('Tukey Test for scary_dist_edgy_thrill')
print(' ')

mc1 = multi.MultiComparison(movie_sent['scary_dist_edgy_thrill'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for scary_dist_edgy_thrill
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0044    0.9 -0.0218  0.0129  False
#      0      3  -0.0036    0.9 -0.0216  0.0144  False
#      0      4   0.1252  0.001  0.1049  0.1454   True
#      0      5    0.288  0.001  0.2694  0.3065   True
#      0      6   0.2131  0.001  0.1954  0.2308   True
#      0      7   0.1453  0.001  0.1279  0.1627   True
#      0      8   0.0113 0.5153 -0.0059  0.0285  False
#      0      9   0.0965  0.001  0.0779   0.115   True
#      1      3   0.0008    0.9 -0.0127  0.0144  False
#      1      4   0.1296  0.001  0.1131   0.146   True
#      1      5   0.2924  0.001   0.278  0.3068   True
#      1      6   0.2176  0.001  0.2043  0.2308   True
#      1      7   0.1497  0.001  0.1369  0.1625   True
#      1      8   0.0157 0.0033  0.0032  0.0282   True
# ...

# %%
print('Tukey Test for thirlling_susp')
print(' ')

mc1 = multi.MultiComparison(movie_sent['thirlling_susp'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for thirlling_susp
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0441 0.0065  -0.081 -0.0072   True
#      0      3  -0.0087    0.9 -0.0469  0.0294  False
#      0      4   0.3457  0.001  0.3027  0.3887   True
#      0      5   0.4374  0.001  0.3979  0.4769   True
#      0      6   0.4147  0.001   0.377  0.4523   True
#      0      7   0.4134  0.001  0.3764  0.4504   True
#      0      8  -0.0153    0.9 -0.0518  0.0213  False
#      0      9   0.1886  0.001  0.1492  0.2281   True
#      1      3   0.0354 0.0044  0.0066  0.0642   True
#      1      4   0.3898  0.001  0.3548  0.4248   True
#      1      5   0.4815  0.001   0.451  0.5121   True
#      1      6   0.4588  0.001  0.4307  0.4869   True
#      1      7   0.4575  0.001  0.4302  0.4848   True
#      1      8   0.0289 0.0219  0.0023  0.0555   True
# ...

# %%
print('Tukey Test for disturbing')
print(' ')

mc1 = multi.MultiComparison(movie_sent['dramatic'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for disturbing
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0586  0.001 -0.0874 -0.0297   True
#      0      3  -0.1606  0.001 -0.1905 -0.1308   True
#      0      4   0.0175 0.7703 -0.0161  0.0511  False
#      0      5  -0.0625  0.001 -0.0934 -0.0316   True
#      0      6   0.0856  0.001  0.0561   0.115   True
#      0      7  -0.0093    0.9 -0.0382  0.0197  False
#      0      8  -0.1756  0.001 -0.2041  -0.147   True
#      0      9   0.0827  0.001  0.0519  0.1136   True
#      1      3  -0.1021  0.001 -0.1246 -0.0795   True
#      1      4   0.0761  0.001  0.0487  0.1034   True
#      1      5  -0.0039    0.9 -0.0278    0.02  False
#      1      6   0.1441  0.001  0.1222  0.1661   True
#      1      7   0.0493  0.001  0.0279  0.0706   True
#      1      8   -0.117  0.001 -0.1378 -0.0962   True
# ...

# %% [markdown]
# # KM11_7

# %%
KM11_7 = pd.DataFrame(c.iloc[:, 6])
KM11_7.columns = ['KM11_7']
print('Top positive correlation')
print(' ')
KM11_7.sort_values(by='KM11_7', ascending = False).head()
# Out:
# Top positive correlation
#                                 KM11_7
# fastpaced                     0.651884
# fastpaced_thrilling_exciting  0.557974
# exciting                      0.529396
# thirlling_susp                0.393723
# scary_dist_edgy_thrill        0.185097

# %%
print('Top Negative Correlation')
print(' ')
KM11_7.sort_values(by='KM11_7', ascending = False).tail()
# Out:
# Top Negative Correlation
#                                 KM11_7
# calming                      -0.250928
# wholesome                    -0.261817
# relatable                    -0.288376
# touching                     -0.291568
# touching_wholesome_uplifting -0.296553

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fastpaced', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fastpaced_thrilling_exciting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='exciting', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='thirlling_susp', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='scary_dist_edgy_thrill', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for fastpaced')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fastpaced'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fastpaced
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0001    0.9 -0.0252   0.025  False
#      0      3   0.0378  0.001  0.0118  0.0637   True
#      0      4   0.1861  0.001  0.1569  0.2153   True
#      0      5   0.0771  0.001  0.0503   0.104   True
#      0      6    0.122  0.001  0.0964  0.1476   True
#      0      7   0.2968  0.001  0.2716   0.322   True
#      0      8   0.0645  0.001  0.0396  0.0893   True
#      0      9   0.0507  0.001  0.0238  0.0775   True
#      1      3   0.0379  0.001  0.0183  0.0575   True
#      1      4   0.1862  0.001  0.1625    0.21   True
#      1      5   0.0773  0.001  0.0565   0.098   True
#      1      6   0.1222  0.001   0.103  0.1413   True
#      1      7   0.2969  0.001  0.2784  0.3155   True
#      1      8   0.0646  0.001  0.0465  0.0827   True
# ...

# %%
print('Tukey Test for exciting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['exciting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for exciting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0238 0.1225 -0.0504  0.0028  False
#      0      3   0.0449  0.001  0.0174  0.0724   True
#      0      4   0.2127  0.001  0.1817  0.2437   True
#      0      5   0.0319 0.0147  0.0035  0.0604   True
#      0      6   0.1123  0.001  0.0852  0.1394   True
#      0      7    0.231  0.001  0.2043  0.2576   True
#      0      8    0.017 0.5338 -0.0093  0.0433  False
#      0      9   0.0347 0.0049  0.0062  0.0631   True
#      1      3   0.0687  0.001  0.0479  0.0895   True
#      1      4   0.2365  0.001  0.2113  0.2617   True
#      1      5   0.0557  0.001  0.0337  0.0777   True
#      1      6   0.1361  0.001  0.1158  0.1563   True
#      1      7   0.2548  0.001  0.2351  0.2744   True
#      1      8   0.0408  0.001  0.0216    0.06   True
# ...

# %%
print('Tukey Test for fastpaced_thrilling_exciting')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fastpaced_thrilling_exciting'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fastpaced_thrilling_exciting
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0227 0.0882 -0.0469  0.0016  False
#      0      3   0.0246 0.0589 -0.0004  0.0497  False
#      0      4   0.2482  0.001  0.2199  0.2764   True
#      0      5   0.1822  0.001  0.1562  0.2081   True
#      0      6   0.2163  0.001  0.1916  0.2411   True
#      0      7   0.3137  0.001  0.2894  0.3381   True
#      0      8   0.0221 0.1012  -0.002  0.0461  False
#      0      9   0.0913  0.001  0.0654  0.1173   True
#      1      3   0.0473  0.001  0.0284  0.0663   True
#      1      4   0.2708  0.001  0.2478  0.2938   True
#      1      5   0.2048  0.001  0.1848  0.2249   True
#      1      6    0.239  0.001  0.2205  0.2575   True
#      1      7   0.3364  0.001  0.3185  0.3543   True
#      1      8   0.0448  0.001  0.0273  0.0623   True
# ...

# %%
print('Tukey Test for thirlling_susp')
print(' ')

mc1 = multi.MultiComparison(movie_sent['thirlling_susp'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for thirlling_susp
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0441 0.0065  -0.081 -0.0072   True
#      0      3  -0.0087    0.9 -0.0469  0.0294  False
#      0      4   0.3457  0.001  0.3027  0.3887   True
#      0      5   0.4374  0.001  0.3979  0.4769   True
#      0      6   0.4147  0.001   0.377  0.4523   True
#      0      7   0.4134  0.001  0.3764  0.4504   True
#      0      8  -0.0153    0.9 -0.0518  0.0213  False
#      0      9   0.1886  0.001  0.1492  0.2281   True
#      1      3   0.0354 0.0044  0.0066  0.0642   True
#      1      4   0.3898  0.001  0.3548  0.4248   True
#      1      5   0.4815  0.001   0.451  0.5121   True
#      1      6   0.4588  0.001  0.4307  0.4869   True
#      1      7   0.4575  0.001  0.4302  0.4848   True
#      1      8   0.0289 0.0219  0.0023  0.0555   True
# ...

# %%
print('Tukey Test for scary_dist_edgy_thrill')
print(' ')

mc1 = multi.MultiComparison(movie_sent['scary_dist_edgy_thrill'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for scary_dist_edgy_thrill
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0044    0.9 -0.0218  0.0129  False
#      0      3  -0.0036    0.9 -0.0216  0.0144  False
#      0      4   0.1252  0.001  0.1049  0.1454   True
#      0      5    0.288  0.001  0.2694  0.3065   True
#      0      6   0.2131  0.001  0.1954  0.2308   True
#      0      7   0.1453  0.001  0.1279  0.1627   True
#      0      8   0.0113 0.5153 -0.0059  0.0285  False
#      0      9   0.0965  0.001  0.0779   0.115   True
#      1      3   0.0008    0.9 -0.0127  0.0144  False
#      1      4   0.1296  0.001  0.1131   0.146   True
#      1      5   0.2924  0.001   0.278  0.3068   True
#      1      6   0.2176  0.001  0.2043  0.2308   True
#      1      7   0.1497  0.001  0.1369  0.1625   True
#      1      8   0.0157 0.0033  0.0032  0.0282   True
# ...

# %% [markdown]
# # KM11_8

# %%
KM11_8 = pd.DataFrame(c.iloc[:, 7])
KM11_8.columns = ['KM11_8']
print('Top positive correlation')
print(' ')
KM11_8.sort_values(by='KM11_8', ascending = False).head()
# Out:
# Top positive correlation
#                        KM11_8
# fun_outrag_mindless  0.640168
# mindless             0.610112
# fun_funny            0.557050
# outrageous           0.498566
# shallow              0.446470

# %%
print('Top Negative Correlation')
print(' ')
KM11_8.sort_values(by='KM11_8', ascending = False).tail()
# Out:
# Top Negative Correlation
#                               KM11_8
# info_real_int_insp         -0.317112
# deep                       -0.350018
# thirlling_susp             -0.361819
# sad_dramatic_deep_touching -0.432298
# dramatic                   -0.436166

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fun_outrag_mindless', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='mindless', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='fun_funny', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='outrageous', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='shallow', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for fun_outrag_mindless')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fun_outrag_mindless'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fun_outrag_mindless
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0392  0.001  0.0187  0.0597   True
#      0      3   0.1423  0.001   0.121  0.1635   True
#      0      4   0.0522  0.001  0.0283  0.0761   True
#      0      5  -0.0241  0.019  -0.046 -0.0022   True
#      0      6  -0.0414  0.001 -0.0623 -0.0205   True
#      0      7   0.0218 0.0286  0.0012  0.0424   True
#      0      8   0.2173  0.001   0.197  0.2376   True
#      0      9  -0.0459  0.001 -0.0678 -0.0239   True
#      1      3   0.1031  0.001   0.087  0.1191   True
#      1      4   0.0129 0.4957 -0.0065  0.0324  False
#      1      5  -0.0633  0.001 -0.0803 -0.0463   True
#      1      6  -0.0806  0.001 -0.0962  -0.065   True
#      1      7  -0.0174 0.0111 -0.0326 -0.0023   True
#      1      8   0.1781  0.001  0.1633  0.1929   True
# ...

# %%
print('Tukey Test for fun_funny')
print(' ')

mc1 = multi.MultiComparison(movie_sent['fun_funny'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for fun_funny
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#      0      1    0.075 0.001  0.0245  0.1254   True
#      0      3   0.3585 0.001  0.3063  0.4107   True
#      0      4   0.0806 0.001  0.0218  0.1394   True
#      0      5  -0.1718 0.001 -0.2258 -0.1178   True
#      0      6  -0.1801 0.001 -0.2316 -0.1286   True
#      0      7  -0.0165   0.9 -0.0672  0.0341  False
#      0      8    0.424 0.001  0.3741   0.474   True
#      0      9  -0.1666 0.001 -0.2206 -0.1126   True
#      1      3   0.2835 0.001  0.2441  0.3229   True
#      1      4   0.0056   0.9 -0.0422  0.0535  False
#      1      5  -0.2468 0.001 -0.2885  -0.205   True
#      1      6  -0.2551 0.001 -0.2935 -0.2166   True
#      1      7  -0.0915 0.001 -0.1288 -0.0542   True
#      1      8   0.3491 0.001  0.3127  0.3855   True
# ...

# %%
print('Tukey Test for mindless')
print(' ')

mc1 = multi.MultiComparison(movie_sent['mindless'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for mindless
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0364  0.001  0.0245  0.0484   True
#      0      3   0.0383  0.001  0.0259  0.0506   True
#      0      4   0.0201  0.001  0.0062   0.034   True
#      0      5   0.0433  0.001  0.0305  0.0561   True
#      0      6   0.0161 0.0014  0.0039  0.0283   True
#      0      7   0.0324  0.001  0.0204  0.0444   True
#      0      8   0.1135  0.001  0.1017  0.1253   True
#      0      9   0.0128 0.0503    -0.0  0.0255  False
#      1      3   0.0018    0.9 -0.0075  0.0111  False
#      1      4  -0.0164  0.001 -0.0277  -0.005   True
#      1      5   0.0069 0.4402  -0.003  0.0167  False
#      1      6  -0.0204  0.001 -0.0295 -0.0113   True
#      1      7  -0.0041 0.8845 -0.0129  0.0048  False
#      1      8    0.077  0.001  0.0684  0.0857   True
# ...

# %%
print('Tukey Test for outrageous')
print(' ')

mc1 = multi.MultiComparison(movie_sent['outrageous'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for outrageous
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1   0.0062    0.9 -0.0088  0.0212  False
#      0      3   0.0301  0.001  0.0145  0.0456   True
#      0      4   0.0558  0.001  0.0383  0.0732   True
#      0      5   0.0562  0.001  0.0402  0.0722   True
#      0      6   0.0399  0.001  0.0246  0.0552   True
#      0      7   0.0495  0.001  0.0345  0.0645   True
#      0      8   0.1144  0.001  0.0996  0.1293   True
#      0      9   0.0162 0.0445  0.0002  0.0323   True
#      1      3   0.0239  0.001  0.0121  0.0356   True
#      1      4   0.0496  0.001  0.0354  0.0638   True
#      1      5     0.05  0.001  0.0376  0.0624   True
#      1      6   0.0337  0.001  0.0222  0.0451   True
#      1      7   0.0433  0.001  0.0322  0.0544   True
#      1      8   0.1082  0.001  0.0974  0.1191   True
# ...

# %%
print('Tukey Test for dramatic')
print(' ')

mc1 = multi.MultiComparison(movie_sent['dramatic'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for dramatic
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0586  0.001 -0.0874 -0.0297   True
#      0      3  -0.1606  0.001 -0.1905 -0.1308   True
#      0      4   0.0175 0.7703 -0.0161  0.0511  False
#      0      5  -0.0625  0.001 -0.0934 -0.0316   True
#      0      6   0.0856  0.001  0.0561   0.115   True
#      0      7  -0.0093    0.9 -0.0382  0.0197  False
#      0      8  -0.1756  0.001 -0.2041  -0.147   True
#      0      9   0.0827  0.001  0.0519  0.1136   True
#      1      3  -0.1021  0.001 -0.1246 -0.0795   True
#      1      4   0.0761  0.001  0.0487  0.1034   True
#      1      5  -0.0039    0.9 -0.0278    0.02  False
#      1      6   0.1441  0.001  0.1222  0.1661   True
#      1      7   0.0493  0.001  0.0279  0.0706   True
#      1      8   -0.117  0.001 -0.1378 -0.0962   True
# ...

# %% [markdown]
# # KM11_9

# %%
KM11_9 = pd.DataFrame(c.iloc[:, 8])
KM11_9.columns = ['KM11_9']
print('Top positive correlation')
print(' ')
KM11_9.sort_values(by='KM11_9', ascending = False).head()
# Out:
# Top positive correlation
#                               KM11_9
# informative                 0.590297
# info_real_int_insp          0.562750
# real                        0.531000
# deep                        0.393314
# sad_dramatic_deep_touching  0.370719

# %%
print('Top Negative Correlation')
print(' ')
KM11_9.sort_values(by='KM11_9', ascending = False).tail()
# Out:
# Top Negative Correlation
#                        KM11_9
# imaginative         -0.159621
# mindless            -0.178581
# fake                -0.186860
# fun_funny           -0.273703
# fun_outrag_mindless -0.280093

# %%
a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='informative', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='info_real_int_insp', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='real', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='sad_dramatic_deep_touching', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

a4_dims = (8, 8) ### to make a bigger image just change this values

fig, ax = pyplot.subplots(figsize=a4_dims)

sns.boxplot(y='deep', x='KM11', 
                 data=movie_sent, 
                 palette="colorblind")

# %%
print('Tukey Test for informative')
print(' ')

mc1 = multi.MultiComparison(movie_sent['informative'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for informative
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0802  0.001 -0.1004 -0.0601   True
#      0      3   -0.093  0.001 -0.1138 -0.0721   True
#      0      4  -0.0868  0.001 -0.1103 -0.0634   True
#      0      5  -0.0933  0.001 -0.1148 -0.0717   True
#      0      6  -0.0431  0.001 -0.0637 -0.0226   True
#      0      7  -0.0934  0.001 -0.1136 -0.0731   True
#      0      8  -0.1018  0.001 -0.1217 -0.0818   True
#      0      9   0.0967  0.001  0.0751  0.1182   True
#      1      3  -0.0128 0.2242 -0.0285   0.003  False
#      1      4  -0.0066    0.9 -0.0257  0.0125  False
#      1      5   -0.013 0.2681 -0.0297  0.0036  False
#      1      6   0.0371  0.001  0.0217  0.0524   True
#      1      7  -0.0131 0.1355  -0.028  0.0018  False
#      1      8  -0.0215  0.001 -0.0361  -0.007   True
# ...

# %%
print('Tukey Test for real')
print(' ')

mc1 = multi.MultiComparison(movie_sent['real'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for real
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1196  0.001  -0.139 -0.1003   True
#      0      3  -0.1621  0.001 -0.1822 -0.1421   True
#      0      4  -0.1848  0.001 -0.2074 -0.1622   True
#      0      5  -0.1844  0.001 -0.2052 -0.1637   True
#      0      6  -0.1095  0.001 -0.1292 -0.0897   True
#      0      7  -0.1833  0.001 -0.2027 -0.1638   True
#      0      8    -0.18  0.001 -0.1992 -0.1608   True
#      0      9    0.018 0.1496 -0.0027  0.0387  False
#      1      3  -0.0425  0.001 -0.0576 -0.0274   True
#      1      4  -0.0652  0.001 -0.0835 -0.0468   True
#      1      5  -0.0648  0.001 -0.0808 -0.0487   True
#      1      6   0.0102 0.4496 -0.0046  0.0249  False
#      1      7  -0.0636  0.001  -0.078 -0.0493   True
#      1      8  -0.0604  0.001 -0.0744 -0.0464   True
# ...

# %%
print('Tukey Test for info_real_int_insp')
print(' ')

mc1 = multi.MultiComparison(movie_sent['info_real_int_insp'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for info_real_int_insp
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1287  0.001 -0.1427 -0.1146   True
#      0      3  -0.1452  0.001 -0.1597 -0.1307   True
#      0      4  -0.1186  0.001  -0.135 -0.1023   True
#      0      5  -0.1797  0.001 -0.1948 -0.1647   True
#      0      6  -0.1068  0.001 -0.1212 -0.0925   True
#      0      7  -0.1612  0.001 -0.1753 -0.1471   True
#      0      8  -0.1799  0.001 -0.1938  -0.166   True
#      0      9   0.0047    0.9 -0.0103  0.0198  False
#      1      3  -0.0165  0.001 -0.0275 -0.0056   True
#      1      4     0.01 0.3225 -0.0033  0.0233  False
#      1      5  -0.0511  0.001 -0.0627 -0.0394   True
#      1      6   0.0218  0.001  0.0111  0.0325   True
#      1      7  -0.0325  0.001 -0.0429 -0.0221   True
#      1      8  -0.0513  0.001 -0.0614 -0.0411   True
# ...

# %%
print('Tukey Test for sad_dramatic_deep_touching')
print(' ')

mc1 = multi.MultiComparison(movie_sent['sad_dramatic_deep_touching'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for sad_dramatic_deep_touching
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.1263  0.001  -0.144 -0.1086   True
#      0      3  -0.1754  0.001 -0.1937  -0.157   True
#      0      4   -0.149  0.001 -0.1697 -0.1284   True
#      0      5  -0.1883  0.001 -0.2073 -0.1694   True
#      0      6  -0.1079  0.001  -0.126 -0.0898   True
#      0      7  -0.1846  0.001 -0.2024 -0.1669   True
#      0      8  -0.2336  0.001 -0.2512 -0.2161   True
#      0      9  -0.0506  0.001 -0.0695 -0.0316   True
#      1      3  -0.0491  0.001 -0.0629 -0.0352   True
#      1      4  -0.0227  0.001 -0.0395 -0.0059   True
#      1      5   -0.062  0.001 -0.0767 -0.0474   True
#      1      6   0.0184  0.001  0.0049  0.0319   True
#      1      7  -0.0583  0.001 -0.0715 -0.0452   True
#      1      8  -0.1073  0.001 -0.1201 -0.0946   True
# ...

# %%
print('Tukey Test for dramatic')
print(' ')

mc1 = multi.MultiComparison(movie_sent['dramatic'], movie_sent['KM11'])  # Change cluster variable and sentiment
res1 = mc1.tukeyhsd() 
print(res1.summary())
# Out:
# Tukey Test for dramatic
#
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      0      1  -0.0586  0.001 -0.0874 -0.0297   True
#      0      3  -0.1606  0.001 -0.1905 -0.1308   True
#      0      4   0.0175 0.7703 -0.0161  0.0511  False
#      0      5  -0.0625  0.001 -0.0934 -0.0316   True
#      0      6   0.0856  0.001  0.0561   0.115   True
#      0      7  -0.0093    0.9 -0.0382  0.0197  False
#      0      8  -0.1756  0.001 -0.2041  -0.147   True
#      0      9   0.0827  0.001  0.0519  0.1136   True
#      1      3  -0.1021  0.001 -0.1246 -0.0795   True
#      1      4   0.0761  0.001  0.0487  0.1034   True
#      1      5  -0.0039    0.9 -0.0278    0.02  False
#      1      6   0.1441  0.001  0.1222  0.1661   True
#      1      7   0.0493  0.001  0.0279  0.0706   True
#      1      8   -0.117  0.001 -0.1378 -0.0962   True
# ...
